# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df

# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# ...

# %%
df.isnull().sum()   #is used in pandas to check for missing values in a DataFrame
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]         #showing city with null value
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed city  \
# 0              2    Australia    Sri Lanka   0.1     0                0  NaN
# 1              2    Australia    Sri Lanka   0.2     0                0  NaN
# 2              2    Australia    Sri Lanka   0.3     1                0  NaN
# 3              2    Australia    Sri Lanka   0.4     2                0  NaN
# 4              2    Australia    Sri Lanka   0.5     0                0  NaN
# ...          ...          ...          ...   ...   ...              ...  ...
# 115194       963    Australia    Sri Lanka  19.2     1                0  NaN
# 115195       963    Australia    Sri Lanka  19.3     4                0  NaN
# 115196       963    Australia    Sri Lanka  19.4     4                0  NaN
# 115197       963    Australia    Sri Lanka  19.5     6                0  NaN
# 115198       963    Australia    Sri Lanka  19.6     0          TM Head  NaN
#
# ...

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
df['venue'].str.split() #split the data
# Out:
# 0         [Melbourne, Cricket, Ground]
# 1         [Melbourne, Cricket, Ground]
# 2         [Melbourne, Cricket, Ground]
# 3         [Melbourne, Cricket, Ground]
# 4         [Melbourne, Cricket, Ground]
#                       ...
# 115320         [R, Premadasa, Stadium]
# 115321         [R, Premadasa, Stadium]
# 115322         [R, Premadasa, Stadium]
# 115323         [R, Premadasa, Stadium]
# 115324         [R, Premadasa, Stadium]
# Name: venue, Length: 63888, dtype: object

# %%
df['venue'].str.split().apply(lambda x:x[0])  # spliting and taking out the first word
# Out:
# 0         Melbourne
# 1         Melbourne
# 2         Melbourne
# 3         Melbourne
# 4         Melbourne
#             ...
# 115320            R
# 115321            R
# 115322            R
# 115323            R
# 115324            R
# Name: venue, Length: 63888, dtype: object

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
cities
# Out:
# array(['Melbourne', 'Melbourne', 'Melbourne', ..., 'Colombo', 'Colombo',
#        'Colombo'], dtype=object)

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city                     venue
# 0       Melbourne  Melbourne Cricket Ground
# ...

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %% [markdown]
# Calculates the Cumulative Sum of Runs for Each Match

# %%
df = df.copy()
df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score
# 0       Melbourne              0
# 1       Melbourne              0
# ...

# %% [markdown]
# Extracting the Over Number & Ball Number within the Over:

# %%
df.loc[:, 'over'] = df['ball'].apply(lambda x: str(x).split(".")[0])
df.loc[:, 'ball_no'] = df['ball'].apply(lambda x: str(x).split(".")[1])
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no
# 0       Melbourne              0    0       1
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no  balls_bowled
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score over ball_no  balls_bowled  balls_left
# ...

# %%
# Ensure that 'player_dismissed' is treated as numeric, handling possible non-numeric values
df['player_dismissed'] = pd.to_numeric(df['player_dismissed'], errors='coerce')  # This will convert non-numeric values to NaN
df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 0 if x == 0 else 1)  # Convert 0s to 0, others to 1
df['player_dismissed'] = df['player_dismissed'].astype('int')  # Convert to integer type

# Now perform the cumulative sum
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# Calculate wickets left
df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
# Convert 'runs' to numeric, coercing errors to NaN, then drop NaNs
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')
df = df.dropna(subset=['runs'])

# %%
groups = df.groupby('match_id')
match_ids = df['match_id'].unique()
last_five = []

for id in match_ids:
    group_runs = groups.get_group(id)['runs']
    last_five.extend(group_runs.rolling(window=30).sum().tolist())

# %%
df['last_five'] = last_five

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 0
# 1              2    Australia    Sri Lanka   0.2     0                 0
# 2              2    Australia    Sri Lanka   0.3     1                 0
# 3              2    Australia    Sri Lanka   0.4     2                 0
# 4              2    Australia    Sri Lanka   0.5     0                 0
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1                 8
# 115321       964    Sri Lanka    Australia  19.4     0                 8
# 115322       964    Sri Lanka    Australia  19.5     0                 9
# 115323       964    Sri Lanka    Australia  19.6     2                 9
# 115324       964    Sri Lanka    Australia  19.7     1                 9
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df
# Out:
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0             2     168    Australia    Sri Lanka   0.1       0
# 1             2     168    Australia    Sri Lanka   0.2       0
# 2             2     168    Australia    Sri Lanka   0.3       1
# 3             2     168    Australia    Sri Lanka   0.4       2
# 4             2     168    Australia    Sri Lanka   0.5       0
# ...         ...     ...          ...          ...   ...     ...
# 50496       964     128    Sri Lanka    Australia  19.3       1
# 50497       964     128    Sri Lanka    Australia  19.4       0
# 50498       964     128    Sri Lanka    Australia  19.5       0
# 50499       964     128    Sri Lanka    Australia  19.6       2
# 50500       964     128    Sri Lanka    Australia  19.7       1
#
#        player_dismissed       city  current_score over ball_no  balls_bowled  \
# 0                     0  Melbourne              0    0       1             1
# ...

# %%
import pickle
pickle.dump(final_df,open('dataset_level5.pkl','wb'))

# %%
import pickle
import pandas as pd

# Load the pickle file
final_df = pickle.load(open('dataset_level5.pkl', 'rb'))

# Convert the DataFrame to CSV
final_df.to_csv('dataset_level5.csv', index=False)

print("File converted to CSV and saved as 'dataset_level5.csv'")
# Out:
# File converted to CSV and saved as 'dataset_level5.csv'

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 50496    Sri Lanka    Australia    Colombo            125           3
# 50497    Sri Lanka    Australia    Colombo            125           2
# 50498    Sri Lanka    Australia    Colombo            125           1
# 50499    Sri Lanka    Australia    Colombo            127           0
# 50500    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# ...

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12024
# runs_x               0
# dtype: int64

# %%
final_df_copy = final_df.copy()
final_df_copy.dropna(inplace=True)

# %%
final_df.loc[final_df.index, :] = final_df.dropna()

# %%
final_df = final_df.dropna()

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 29       Australia    Sri Lanka  Melbourne           43.0        90.0
# 30       Australia    Sri Lanka  Melbourne           44.0        89.0
# 31       Australia    Sri Lanka  Melbourne           45.0        88.0
# 32       Australia    Sri Lanka  Melbourne           45.0        87.0
# 33       Australia    Sri Lanka  Melbourne           45.0        86.0
# ...            ...          ...        ...            ...         ...
# 50496    Sri Lanka    Australia    Colombo          125.0         3.0
# 50497    Sri Lanka    Australia    Colombo          125.0         2.0
# 50498    Sri Lanka    Australia    Colombo          125.0         1.0
# 50499    Sri Lanka    Australia    Colombo          127.0         0.0
# 50500    Sri Lanka    Australia    Colombo          128.0         0.0
#
#        wickets_left       crr  last_five  runs_x
# 29             10.0  8.600000       43.0   168.0
# ...

# %%
import pickle
pickle.dump(final_df,open('dataset_level9.pkl','wb'))

# %%
import pickle
import pandas as pd

# Load the pickle file
final_df = pickle.load(open('dataset_level5.pkl', 'rb'))

# Convert the DataFrame to CSV
final_df.to_csv('dataset_level5.csv', index=False)

print("File converted to CSV and saved as 'dataset_level5.csv'")

# %%
final_df = final_df.sample(final_df.shape[0])    #suffling the data unbaising

# %%
final_df
# Out:
#        batting_team bowling_team          city  current_score  balls_left  \
# 40165    Bangladesh        India        Mirpur          104.0        23.0
# 31603       England  Afghanistan       Colombo          193.0         3.0
# 30678     Sri Lanka     Pakistan     Abu Dhabi           88.0        63.0
# 39605  South Africa  New Zealand    Chittagong           40.0        83.0
# 1045          India      England     Bangalore           72.0        64.0
# ...             ...          ...           ...            ...         ...
# 20739     Sri Lanka     Pakistan        London          113.0        33.0
# 13910  South Africa      England     Cape Town          150.0        15.0
# 15844         India     Pakistan        Durban           62.0        61.0
# 15405   West Indies      England        London          168.0         2.0
# 15119  South Africa        India  Johannesburg           77.0        37.0
#
#        wickets_left       crr  last_five  runs_x
# ...

# %%
final_df.sample(2)
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 48007      England  Afghanistan      Delhi           50.0        72.0
# 8827      Pakistan  New Zealand  Abu Dhabi          142.0         1.0
#
#        wickets_left       crr  last_five  runs_x
# 48007           6.0  6.250000       34.0   142.0
# 8827            4.0  7.159664       41.0   148.0

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team  bowling_team        city  current_score  balls_left  \
# 15010     Sri Lanka   New Zealand    Auckland           72.0        31.0
# 8427       Pakistan     Australia   Abu Dhabi          114.0        30.0
# 9745   South Africa       England   Centurion          155.0        30.0
# 37019     Sri Lanka    Bangladesh   Pallekele          111.0        38.0
# 35427   New Zealand  South Africa      Durban           27.0        82.0
# ...             ...           ...         ...            ...         ...
# 6311     Bangladesh         India     Colombo           89.0        43.0
# 27091     Sri Lanka         India      Nagpur           54.0        76.0
# 1112          India       England   Bangalore          202.0         0.0
# 16516  South Africa       England   Cape Town          121.0        14.0
# 48243     Australia      Pakistan  Chandigarh           54.0        82.0
#
#        wickets_left        crr  last_five
# 15010           2.0   4.853933       17.0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.1

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer(
    transformers=[
        ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
    ],
    remainder='passthrough'
)

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9872188055616608
# 1.6641517974234916

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '2.1.2'

# %%
mys = pickle.load(open('pipe.pkl'','wb'))
# Out:
#   Cell In[57], line 1
#     mys = pickle.load(open('pipe.pkl'','wb'))
#                                           ^
# SyntaxError: unterminated string literal (detected at line 1)
